# %% [markdown]
# <a href="https://colab.research.google.com/github/gwfbrave297-hash/labo2025v/blob/main/src/ensembles/594_TareaHogar_05-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 10:34:39 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660381 35.3 1454474    77.7 1454474  77.7
# Vcells 1226627  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5941
PARAM$semilla_primigenia <- 557057

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  # scale_pos_weight= 1.0, # scale_pos_weight > 0.0 - removed as it conflicts with is_unbalance

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower= 16L, upper= 512L),
  makeIntegerParam("max_depth", lower= 3L, upper= 15L),
  makeNumericParam("learning_rate=",lower= 0.005, upper= 0.3),
  makeIntegerParam("n_estimators", lower= 200L, upper= 3000L),
  makeIntegerParam("min_data_in_leaf", lower= 10L, upper= 200L),
  makeIntegerParam("bagging_freq",lower= 1L, upper= 10L),
  makeNumericParam("bagging_fraction=",lower= 0.5, upper= 1.0),
  makeNumericParam("feature_fraction=",lower= 0.5, upper= 1.0),
  makeIntegerParam("scale_pos_weight",lower= 50L, upper= 150L)
  #makeNumericParam("lambda_l1= ",lower= 0.01, upper= 100),
  #makeNumericParam("lambda_l2= ",lower= 0.01, upper= 100)
  #makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  #makeNumericParam("learning_rate", lower= 0.01, upper= 0.3)

)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 75 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(879979, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) & # Changed from c(879979) to c(202107)
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83336
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Nov 03 11:08:32 PM 2025 AUC 0.924033611032986
#
# Mon Nov 03 11:14:19 PM 2025 AUC 0.924058843332756
#
# Mon Nov 03 11:20:02 PM 2025 AUC 0.925447157847776
#
# Mon Nov 03 11:24:57 PM 2025 AUC 0.920850695202716
#
# Mon Nov 03 11:29:23 PM 2025 AUC 0.924966495309527
#
# Mon Nov 03 11:34:24 PM 2025 AUC 0.923522179596988
#
# Mon Nov 03 11:40:48 PM 2025 AUC 0.927175114615731
#
# Mon Nov 03 11:44:57 PM 2025 AUC 0.925243885113689
#
# Mon Nov 03 11:50:39 PM 2025 AUC 0.918888736115184
#
# Mon Nov 03 11:54:29 PM 2025 AUC 0.926014490752387
#
# Mon Nov 03 11:59:22 PM 2025 AUC 0.927479138817704
#
# Tue Nov 04 12:04:53 AM 2025 AUC 0.926217323388808
#
# Tue Nov 04 12:09:28 AM 2025 AUC 0.923474138865581
#
# Tue Nov 04 12:15:38 AM 2025 AUC 0.924011624582156
#
# Tue Nov 04 12:20:13 AM 2025 AUC 0.925879704294273
#
# Tue Nov 04 12:24:12 AM 2025 AUC 0.923876657780114
#
# Tue Nov 04 12:30:14 AM 2025 AUC 0.921753823138373
#
# Tue Nov 04 12:34:11 AM 2025 AUC 0.925292665706673
#
# Tue Nov 04 12:39:21 AM 2025 AUC 0.92345560151333
#
# Tue Nov 04 12:43:20 AM 2025 AUC 0.927113442232774
#
# Tue Nov 04 12:49:16 AM 2025 AUC 0.923204252281133
#
# Tue Nov 04 12:56:05 AM 2025 AUC 0.924296729649059
#
# Tue Nov 04 01:01:42 AM 2025 AUC 0.926765265125032
#
# Tue Nov 04 01:08:23 AM 2025 AUC 0.919793747725435
#
# Tue Nov 04 01:12:49 AM 2025 AUC 0.919430703811988
#
# Tue Nov 04 01:17:00 AM 2025 AUC 0.925303841053151
#
# Tue Nov 04 01:22:03 AM 2025 AUC 0.92526312635871
#
# Tue Nov 04 01:26:11 AM 2025 AUC 0.924210915960818
#
# Tue Nov 04 01:33:20 AM 2025 AUC 0.921125909821881
#
# Tue Nov 04 01:38:36 AM 2025 AUC 0.922813445712586
#
# Tue Nov 04 01:45:41 AM 2025 AUC 0.924362851994346
#
# Tue Nov 04 01:52:16 AM 2025 AUC 0.925445078613787
#
# Tue Nov 04 01:56:02 AM 2025 AUC 0.924720155683941
#
# Tue Nov 04 02:00:34 AM 2025 AUC 0.922867829983213
#
# Tue Nov 04 02:05:01 AM 2025 AUC 0.922641452023125
#
# Tue Nov 04 02:10:21 AM 2025 AUC 0.926715217678771
#
# [mbo] 0: num_leaves=260; max_depth=8; learning_rate==0.194; n_estimators=1127; min_data_in_leaf=88; bagging_freq=5; bagging_fraction==0.651; feature_fraction==0.561; scale_pos_weight=61 : y = 0.924 : 291.7 secs : initdesign
#
# [mbo] 0: num_leaves=173; max_depth=12; learning_rate==0.0334; n_estimators=2202; min_data_in_leaf=120; bagging_freq=8; bagging_fraction==0.755; feature_fraction==0.715; scale_pos_weight=123 : y = 0.924 : 347.9 secs : initdesign
#
# [mbo] 0: num_leaves=138; max_depth=12; learning_rate==0.1; n_estimators=1572; min_data_in_leaf=177; bagging_freq=3; bagging_fraction==0.681; feature_fraction==0.782; scale_pos_weight=108 : y = 0.925 : 342.5 secs : initdesign
#
# [mbo] 0: num_leaves=122; max_depth=8; learning_rate==0.0705; n_estimators=2095; min_data_in_leaf=51; bagging_freq=3; bagging_fraction==0.899; feature_fraction==0.927; scale_pos_weight=97 : y = 0.921 : 294.9 secs : initdesign
#
# [mbo] 0: num_leaves=440; max_depth=6; learning_rate==0.094; n_estimators=481; min_data_in_leaf=144; bagging_freq=1; bagging_fraction==0.743; feature_fraction==0.605; scale_pos_weight=116 : y = 0.925 : 266.6 secs : initdesign
#
# [mbo] 0: num_leaves=79; max_depth=9; learning_rate==0.156; n_estimators=2909; min_data_in_leaf=128; bagging_freq=7; bagging_fraction==0.797; feature_fraction==0.748; scale_pos_weight=113 : y = 0.924 : 300.7 secs : initdesign
#
# [mbo] 0: num_leaves=230; max_depth=15; learning_rate==0.179; n_estimators=2839; min_data_in_leaf=172; bagging_freq=2; bagging_fraction==0.854; feature_fraction==0.729; scale_pos_weight=136 : y = 0.927 : 383.6 secs : initdesign
#
# [mbo] 0: num_leaves=472; max_depth=5; learning_rate==0.072; n_estimators=1861; min_data_in_leaf=154; bagging_freq=4; bagging_fraction==0.819; feature_fraction==0.847; scale_pos_weight=88 : y = 0.925 : 249.6 secs : initdesign
#
# [mbo] 0: num_leaves=197; max_depth=10; learning_rate==0.219; n_estimators=602; min_data_in_leaf=44; bagging_freq=7; bagging_fraction==0.71; feature_fraction==0.676; scale_pos_weight=98 : y = 0.919 : 342.1 secs : initdesign
#
# [mbo] 0: num_leaves=447; max_depth=3; learning_rate==0.261; n_estimators=2011; min_data_in_leaf=111; bagging_freq=8; bagging_fraction==0.933; feature_fraction==0.645; scale_pos_weight=68 : y = 0.926 : 229.5 secs : initdesign
#
# [mbo] 0: num_leaves=51; max_depth=12; learning_rate==0.244; n_estimators=1222; min_data_in_leaf=163; bagging_freq=7; bagging_fraction==0.867; feature_fraction==0.544; scale_pos_weight=92 : y = 0.927 : 293.0 secs : initdesign
#
# [mbo] 0: num_leaves=92; max_depth=15; learning_rate==0.214; n_estimators=801; min_data_in_leaf=136; bagging_freq=6; bagging_fraction==0.628; feature_fraction==0.771; scale_pos_weight=141 : y = 0.926 : 330.9 secs : initdesign
#
# [mbo] 0: num_leaves=107; max_depth=7; learning_rate==0.19; n_estimators=912; min_data_in_leaf=124; bagging_freq=10; bagging_fraction==0.906; feature_fraction==0.947; scale_pos_weight=77 : y = 0.923 : 275.6 secs : initdesign
#
# [mbo] 0: num_leaves=187; max_depth=13; learning_rate==0.0792; n_estimators=2358; min_data_in_leaf=78; bagging_freq=5; bagging_fraction==0.546; feature_fraction==0.658; scale_pos_weight=120 : y = 0.924 : 369.7 secs : initdesign
#
# [mbo] 0: num_leaves=296; max_depth=7; learning_rate==0.151; n_estimators=2402; min_data_in_leaf=152; bagging_freq=7; bagging_fraction==0.781; feature_fraction==0.517; scale_pos_weight=74 : y = 0.926 : 275.4 secs : initdesign
#
# [mbo] 0: num_leaves=398; max_depth=4; learning_rate==0.111; n_estimators=1369; min_data_in_leaf=99; bagging_freq=9; bagging_fraction==0.594; feature_fraction==0.797; scale_pos_weight=144 : y = 0.924 : 238.3 secs : initdesign
#
# [mbo] 0: num_leaves=428; max_depth=11; learning_rate==0.144; n_estimators=1973; min_data_in_leaf=83; bagging_freq=10; bagging_fraction==0.97; feature_fraction==0.969; scale_pos_weight=128 : y = 0.922 : 362.7 secs : initdesign
#
# [mbo] 0: num_leaves=276; max_depth=4; learning_rate==0.0294; n_estimators=584; min_data_in_leaf=57; bagging_freq=6; bagging_fraction==0.824; feature_fraction==0.897; scale_pos_weight=84 : y = 0.925 : 236.7 secs : initdesign
#
# [mbo] 0: num_leaves=353; max_depth=9; learning_rate==0.29; n_estimators=1706; min_data_in_leaf=189; bagging_freq=4; bagging_fraction==0.617; feature_fraction==0.57; scale_pos_weight=147 : y = 0.923 : 309.7 secs : initdesign
#
# [mbo] 0: num_leaves=25; max_depth=4; learning_rate==0.0547; n_estimators=2621; min_data_in_leaf=167; bagging_freq=6; bagging_fraction==0.708; feature_fraction==0.915; scale_pos_weight=59 : y = 0.927 : 239.4 secs : initdesign
#
# [mbo] 0: num_leaves=327; max_depth=11; learning_rate==0.00705; n_estimators=255; min_data_in_leaf=92; bagging_freq=3; bagging_fraction==0.679; feature_fraction==0.535; scale_pos_weight=70 : y = 0.923 : 356.0 secs : initdesign
#
# [mbo] 0: num_leaves=372; max_depth=13; learning_rate==0.17; n_estimators=2481; min_data_in_leaf=60; bagging_freq=2; bagging_fraction==0.664; feature_fraction==0.509; scale_pos_weight=64 : y = 0.924 : 409.3 secs : initdesign
#
# [mbo] 0: num_leaves=463; max_depth=11; learning_rate==0.256; n_estimators=1339; min_data_in_leaf=181; bagging_freq=1; bagging_fraction==0.945; feature_fraction==0.818; scale_pos_weight=90 : y = 0.927 : 336.6 secs : initdesign
#
# [mbo] 0: num_leaves=248; max_depth=14; learning_rate==0.134; n_estimators=1206; min_data_in_leaf=20; bagging_freq=4; bagging_fraction==0.976; feature_fraction==0.866; scale_pos_weight=110 : y = 0.92 : 401.4 secs : initdesign
#
# [mbo] 0: num_leaves=217; max_depth=6; learning_rate==0.204; n_estimators=389; min_data_in_leaf=28; bagging_freq=10; bagging_fraction==0.878; feature_fraction==0.704; scale_pos_weight=150 : y = 0.919 : 266.0 secs : initdesign
#
# [mbo] 0: num_leaves=286; max_depth=5; learning_rate==0.161; n_estimators=2729; min_data_in_leaf=100; bagging_freq=2; bagging_fraction==0.736; feature_fraction==0.62; scale_pos_weight=134 : y = 0.925 : 250.5 secs : initdesign
#
# [mbo] 0: num_leaves=145; max_depth=9; learning_rate==0.272; n_estimators=1500; min_data_in_leaf=200; bagging_freq=5; bagging_fraction==0.568; feature_fraction==0.754; scale_pos_weight=57 : y = 0.925 : 302.9 secs : initdesign
#
# [mbo] 0: num_leaves=68; max_depth=5; learning_rate==0.117; n_estimators=331; min_data_in_leaf=72; bagging_freq=1; bagging_fraction==0.517; feature_fraction==0.976; scale_pos_weight=102 : y = 0.924 : 248.3 secs : initdesign
#
# [mbo] 0: num_leaves=317; max_depth=15; learning_rate==0.018; n_estimators=1768; min_data_in_leaf=20; bagging_freq=9; bagging_fraction==0.601; feature_fraction==0.886; scale_pos_weight=78 : y = 0.921 : 428.7 secs : initdesign
#
# [mbo] 0: num_leaves=512; max_depth=9; learning_rate==0.0503; n_estimators=1634; min_data_in_leaf=108; bagging_freq=2; bagging_fraction==0.542; feature_fraction==0.943; scale_pos_weight=130 : y = 0.923 : 316.2 secs : initdesign
#
# [mbo] 0: num_leaves=404; max_depth=14; learning_rate==0.235; n_estimators=681; min_data_in_leaf=66; bagging_freq=8; bagging_fraction==0.993; feature_fraction==0.627; scale_pos_weight=53 : y = 0.924 : 424.9 secs : initdesign
#
# [mbo] 0: num_leaves=340; max_depth=14; learning_rate==0.226; n_estimators=2581; min_data_in_leaf=142; bagging_freq=9; bagging_fraction==0.58; feature_fraction==0.831; scale_pos_weight=131 : y = 0.925 : 394.5 secs : initdesign
#
# [mbo] 0: num_leaves=384; max_depth=3; learning_rate==0.282; n_estimators=866; min_data_in_leaf=36; bagging_freq=6; bagging_fraction==0.513; feature_fraction==0.596; scale_pos_weight=83 : y = 0.925 : 226.3 secs : initdesign
#
# [mbo] 0: num_leaves=33; max_depth=7; learning_rate==0.126; n_estimators=2975; min_data_in_leaf=11; bagging_freq=10; bagging_fraction==0.775; feature_fraction==0.855; scale_pos_weight=104 : y = 0.923 : 272.4 secs : initdesign
#
# [mbo] 0: num_leaves=498; max_depth=6; learning_rate==0.292; n_estimators=2288; min_data_in_leaf=37; bagging_freq=3; bagging_fraction==0.926; feature_fraction==0.997; scale_pos_weight=50 : y = 0.923 : 266.8 secs : initdesign
#
# [mbo] 0: num_leaves=158; max_depth=10; learning_rate==0.0452; n_estimators=1033; min_data_in_leaf=193; bagging_freq=5; bagging_fraction==0.835; feature_fraction==0.684; scale_pos_weight=120 : y = 0.927 : 320.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Tue Nov 04 02:16:36 AM 2025 AUC 0.927343370032306
#
# [mbo] 1: num_leaves=184; max_depth=15; learning_rate==0.256; n_estimators=1583; min_data_in_leaf=174; bagging_freq=6; bagging_fraction==0.991; feature_fraction==0.531; scale_pos_weight=72 : y = 0.927 : 373.7 secs : infill_ei
#
# Tue Nov 04 02:21:06 AM 2025 AUC 0.927629749923705
#
# [mbo] 2: num_leaves=26; max_depth=13; learning_rate==0.211; n_estimators=619; min_data_in_leaf=193; bagging_freq=7; bagging_fraction==1; feature_fraction==0.592; scale_pos_weight=114 : y = 0.928 : 269.2 secs : infill_ei
#
# Saved the current state after iteration 3 in the file bayesiana.RDATA.
#
# Tue Nov 04 02:24:55 AM 2025 AUC 0.926446992843688
#
# [mbo] 3: num_leaves=30; max_depth=3; learning_rate==0.024; n_estimators=2937; min_data_in_leaf=92; bagging_freq=4; bagging_fraction==0.716; feature_fraction==0.53; scale_pos_weight=50 : y = 0.926 : 228.0 secs : infill_ei
#
# Tue Nov 04 02:30:08 AM 2025 AUC 0.92776591901364
#
# [mbo] 4: num_leaves=85; max_depth=11; learning_rate==0.0855; n_estimators=1088; min_data_in_leaf=193; bagging_freq=7; bagging_fraction==0.99; feature_fraction==0.518; scale_pos_weight=54 : y = 0.928 : 312.1 secs : infill_ei
#
# Tue Nov 04 02:35:31 AM 2025 AUC 0.926155995517022
#
# [mbo] 5: num_leaves=93; max_depth=12; learning_rate==0.233; n_estimators=297; min_data_in_leaf=173; bagging_freq=4; bagging_fraction==1; feature_fraction==0.531; scale_pos_weight=56 : y = 0.926 : 322.0 secs : infill_ei
#
# Saved the current state after iteration 6 in the file bayesiana.RDATA.
#
# Tue Nov 04 02:41:01 AM 2025 AUC 0.927455207070233
#
# [mbo] 6: num_leaves=110; max_depth=12; learning_rate==0.0765; n_estimators=2372; min_data_in_leaf=198; bagging_freq=9; bagging_fraction==0.986; feature_fraction==0.558; scale_pos_weight=90 : y = 0.927 : 328.5 secs : infill_ei
#
# Tue Nov 04 02:45:20 AM 2025 AUC 0.925591292925139
#
# [mbo] 7: num_leaves=20; max_depth=15; learning_rate==0.233; n_estimators=1484; min_data_in_leaf=164; bagging_freq=8; bagging_fraction==0.912; feature_fraction==0.584; scale_pos_weight=124 : y = 0.926 : 259.2 secs : infill_ei
#
# Tue Nov 04 02:51:09 AM 2025 AUC 0.927377180801555
#
# [mbo] 8: num_leaves=335; max_depth=12; learning_rate==0.179; n_estimators=1079; min_data_in_leaf=199; bagging_freq=8; bagging_fraction==0.994; feature_fraction==0.544; scale_pos_weight=84 : y = 0.927 : 347.3 secs : infill_ei
#
# Saved the current state after iteration 9 in the file bayesiana.RDATA.
#
# Tue Nov 04 02:55:39 AM 2025 AUC 0.926366936836698
#
# [mbo] 9: num_leaves=27; max_depth=12; learning_rate==0.133; n_estimators=2117; min_data_in_leaf=196; bagging_freq=6; bagging_fraction==0.96; feature_fraction==0.616; scale_pos_weight=84 : y = 0.926 : 269.5 secs : infill_ei
#
# Tue Nov 04 03:01:19 AM 2025 AUC 0.926940908469006
#
# [mbo] 10: num_leaves=141; max_depth=12; learning_rate==0.226; n_estimators=487; min_data_in_leaf=188; bagging_freq=8; bagging_fraction==0.961; feature_fraction==0.503; scale_pos_weight=91 : y = 0.927 : 339.0 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:07:24 AM 2025 AUC 0.926932488310858
#
# [mbo] 11: num_leaves=403; max_depth=13; learning_rate==0.0897; n_estimators=983; min_data_in_leaf=173; bagging_freq=7; bagging_fraction==0.942; feature_fraction==0.691; scale_pos_weight=56 : y = 0.927 : 364.2 secs : infill_ei
#
# Tue Nov 04 03:13:41 AM 2025 AUC 0.926686422176019
#
# [mbo] 12: num_leaves=388; max_depth=14; learning_rate==0.103; n_estimators=2721; min_data_in_leaf=192; bagging_freq=6; bagging_fraction==0.988; feature_fraction==0.502; scale_pos_weight=73 : y = 0.927 : 375.3 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:19:18 AM 2025 AUC 0.928024308987518
#
# [mbo] 13: num_leaves=102; max_depth=14; learning_rate==0.273; n_estimators=993; min_data_in_leaf=180; bagging_freq=2; bagging_fraction==0.926; feature_fraction==0.511; scale_pos_weight=71 : y = 0.928 : 336.5 secs : infill_ei
#
# Tue Nov 04 03:25:54 AM 2025 AUC 0.926984223002425
#
# [mbo] 14: num_leaves=379; max_depth=15; learning_rate==0.247; n_estimators=1177; min_data_in_leaf=169; bagging_freq=1; bagging_fraction==0.88; feature_fraction==0.617; scale_pos_weight=87 : y = 0.927 : 394.3 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:31:47 AM 2025 AUC 0.926681538234716
#
# [mbo] 15: num_leaves=165; max_depth=13; learning_rate==0.255; n_estimators=1238; min_data_in_leaf=178; bagging_freq=10; bagging_fraction==0.754; feature_fraction==0.517; scale_pos_weight=55 : y = 0.927 : 351.5 secs : infill_ei
#
# Tue Nov 04 03:36:52 AM 2025 AUC 0.927067920912289
#
# [mbo] 16: num_leaves=62; max_depth=13; learning_rate==0.0661; n_estimators=978; min_data_in_leaf=180; bagging_freq=6; bagging_fraction==0.998; feature_fraction==0.502; scale_pos_weight=88 : y = 0.927 : 304.1 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:40:51 AM 2025 AUC 0.926747499683749
#
# [mbo] 17: num_leaves=73; max_depth=4; learning_rate==0.0172; n_estimators=1242; min_data_in_leaf=194; bagging_freq=7; bagging_fraction==0.974; feature_fraction==0.512; scale_pos_weight=52 : y = 0.927 : 238.6 secs : infill_ei
#
# Tue Nov 04 03:46:36 AM 2025 AUC 0.92742207043516
#
# [mbo] 18: num_leaves=125; max_depth=14; learning_rate==0.298; n_estimators=892; min_data_in_leaf=196; bagging_freq=4; bagging_fraction==0.987; feature_fraction==0.879; scale_pos_weight=85 : y = 0.927 : 343.6 secs : infill_ei
#
# Tue Nov 04 03:50:21 AM 2025 AUC 0.926102220637522
#
# [mbo] 19: num_leaves=243; max_depth=3; learning_rate==0.0196; n_estimators=2445; min_data_in_leaf=141; bagging_freq=2; bagging_fraction==0.793; feature_fraction==0.567; scale_pos_weight=50 : y = 0.926 : 224.6 secs : infill_ei
#
# Saved the current state after iteration 20 in the file bayesiana.RDATA.
#
# Tue Nov 04 03:55:37 AM 2025 AUC 0.926624592218899
#
# [mbo] 20: num_leaves=227; max_depth=10; learning_rate==0.0149; n_estimators=1610; min_data_in_leaf=200; bagging_freq=9; bagging_fraction==0.818; feature_fraction==0.597; scale_pos_weight=56 : y = 0.927 : 314.7 secs : infill_ei
#
# Tue Nov 04 04:01:52 AM 2025 AUC 0.927209623095983
#
# [mbo] 21: num_leaves=297; max_depth=14; learning_rate==0.297; n_estimators=2842; min_data_in_leaf=163; bagging_freq=1; bagging_fraction==0.996; feature_fraction==0.554; scale_pos_weight=71 : y = 0.927 : 373.8 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:07:33 AM 2025 AUC 0.926209562291204
#
# [mbo] 22: num_leaves=133; max_depth=13; learning_rate==0.248; n_estimators=1033; min_data_in_leaf=200; bagging_freq=2; bagging_fraction==0.988; feature_fraction==0.612; scale_pos_weight=119 : y = 0.926 : 339.3 secs : infill_ei
#
# Tue Nov 04 04:12:44 AM 2025 AUC 0.928204589024288
#
# [mbo] 23: num_leaves=73; max_depth=14; learning_rate==0.296; n_estimators=1113; min_data_in_leaf=169; bagging_freq=5; bagging_fraction==0.725; feature_fraction==0.557; scale_pos_weight=51 : y = 0.928 : 310.7 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:16:43 AM 2025 AUC 0.925988534199975
#
# [mbo] 24: num_leaves=278; max_depth=4; learning_rate==0.0694; n_estimators=2808; min_data_in_leaf=198; bagging_freq=9; bagging_fraction==0.934; feature_fraction==0.531; scale_pos_weight=81 : y = 0.926 : 237.2 secs : infill_ei
#
# Tue Nov 04 04:22:52 AM 2025 AUC 0.926617297867114
#
# [mbo] 25: num_leaves=209; max_depth=14; learning_rate==0.295; n_estimators=1017; min_data_in_leaf=153; bagging_freq=4; bagging_fraction==0.938; feature_fraction==0.523; scale_pos_weight=51 : y = 0.927 : 368.2 secs : infill_ei
#
# Saved the current state after iteration 26 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:27:57 AM 2025 AUC 0.928847776647374
#
# [mbo] 26: num_leaves=62; max_depth=15; learning_rate==0.295; n_estimators=868; min_data_in_leaf=181; bagging_freq=3; bagging_fraction==0.707; feature_fraction==0.711; scale_pos_weight=52 : y = 0.929 : 303.8 secs : infill_ei
#
# Tue Nov 04 04:32:15 AM 2025 AUC 0.927266006311521
#
# [mbo] 27: num_leaves=20; max_depth=15; learning_rate==0.272; n_estimators=2595; min_data_in_leaf=177; bagging_freq=1; bagging_fraction==0.659; feature_fraction==0.669; scale_pos_weight=52 : y = 0.927 : 256.3 secs : infill_ei
#
# Tue Nov 04 04:37:00 AM 2025 AUC 0.926881683657688
#
# [mbo] 28: num_leaves=43; max_depth=15; learning_rate==0.295; n_estimators=352; min_data_in_leaf=187; bagging_freq=5; bagging_fraction==0.579; feature_fraction==0.733; scale_pos_weight=50 : y = 0.927 : 284.1 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:43:14 AM 2025 AUC 0.927056254755898
#
# [mbo] 29: num_leaves=203; max_depth=15; learning_rate==0.296; n_estimators=2965; min_data_in_leaf=175; bagging_freq=7; bagging_fraction==0.962; feature_fraction==0.899; scale_pos_weight=53 : y = 0.927 : 373.4 secs : infill_ei
#
# Tue Nov 04 04:47:02 AM 2025 AUC 0.926042582655315
#
# [mbo] 30: num_leaves=17; max_depth=3; learning_rate==0.28; n_estimators=939; min_data_in_leaf=166; bagging_freq=6; bagging_fraction==0.766; feature_fraction==0.881; scale_pos_weight=55 : y = 0.926 : 226.6 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Tue Nov 04 04:53:05 AM 2025 AUC 0.927435525180078
#
# [mbo] 31: num_leaves=173; max_depth=15; learning_rate==0.277; n_estimators=1511; min_data_in_leaf=182; bagging_freq=2; bagging_fraction==0.822; feature_fraction==0.754; scale_pos_weight=50 : y = 0.927 : 362.3 secs : infill_ei
#
# Tue Nov 04 04:57:33 AM 2025 AUC 0.929375756193198
#
# [mbo] 32: num_leaves=28; max_depth=15; learning_rate==0.261; n_estimators=372; min_data_in_leaf=175; bagging_freq=1; bagging_fraction==0.702; feature_fraction==0.681; scale_pos_weight=50 : y = 0.929 : 267.0 secs : infill_ei
#
# Saved the current state after iteration 33 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:01:45 AM 2025 AUC 0.927712547561836
#
# [mbo] 33: num_leaves=16; max_depth=15; learning_rate==0.268; n_estimators=677; min_data_in_leaf=173; bagging_freq=1; bagging_fraction==0.677; feature_fraction==0.691; scale_pos_weight=59 : y = 0.928 : 250.3 secs : infill_ei
#
# Tue Nov 04 05:07:01 AM 2025 AUC 0.927256049982512
#
# [mbo] 34: num_leaves=77; max_depth=13; learning_rate==0.298; n_estimators=317; min_data_in_leaf=188; bagging_freq=3; bagging_fraction==0.859; feature_fraction==0.542; scale_pos_weight=63 : y = 0.927 : 314.8 secs : infill_ei
#
# Tue Nov 04 05:12:04 AM 2025 AUC 0.928147589489228
#
# [mbo] 35: num_leaves=60; max_depth=15; learning_rate==0.0831; n_estimators=454; min_data_in_leaf=183; bagging_freq=1; bagging_fraction==0.763; feature_fraction==0.723; scale_pos_weight=50 : y = 0.928 : 300.8 secs : infill_ei
#
# Saved the current state after iteration 36 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:17:34 AM 2025 AUC 0.927177931778386
#
# [mbo] 36: num_leaves=93; max_depth=15; learning_rate==0.19; n_estimators=2699; min_data_in_leaf=177; bagging_freq=1; bagging_fraction==0.727; feature_fraction==0.745; scale_pos_weight=54 : y = 0.927 : 327.8 secs : infill_ei
#
# Tue Nov 04 05:22:44 AM 2025 AUC 0.925654198606256
#
# [mbo] 37: num_leaves=80; max_depth=10; learning_rate==0.0464; n_estimators=1078; min_data_in_leaf=200; bagging_freq=10; bagging_fraction==0.997; feature_fraction==0.861; scale_pos_weight=106 : y = 0.926 : 308.8 secs : infill_ei
#
# Saved the current state after iteration 38 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:28:59 AM 2025 AUC 0.928332908153716
#
# [mbo] 38: num_leaves=195; max_depth=15; learning_rate==0.257; n_estimators=240; min_data_in_leaf=182; bagging_freq=2; bagging_fraction==0.712; feature_fraction==0.619; scale_pos_weight=50 : y = 0.928 : 374.0 secs : infill_ei
#
# Tue Nov 04 05:34:39 AM 2025 AUC 0.926665250939834
#
# [mbo] 39: num_leaves=113; max_depth=14; learning_rate==0.297; n_estimators=2387; min_data_in_leaf=194; bagging_freq=10; bagging_fraction==0.863; feature_fraction==0.5; scale_pos_weight=100 : y = 0.927 : 338.3 secs : infill_ei
#
# Saved the current state after iteration 40 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:38:51 AM 2025 AUC 0.927549200482236
#
# [mbo] 40: num_leaves=17; max_depth=15; learning_rate==0.0377; n_estimators=311; min_data_in_leaf=173; bagging_freq=3; bagging_fraction==0.709; feature_fraction==0.613; scale_pos_weight=50 : y = 0.928 : 251.4 secs : infill_ei
#
# Tue Nov 04 05:44:46 AM 2025 AUC 0.926683624885311
#
# [mbo] 41: num_leaves=168; max_depth=13; learning_rate==0.0109; n_estimators=1148; min_data_in_leaf=175; bagging_freq=1; bagging_fraction==0.87; feature_fraction==0.648; scale_pos_weight=56 : y = 0.927 : 353.3 secs : infill_ei
#
# Saved the current state after iteration 42 in the file bayesiana.RDATA.
#
# Tue Nov 04 05:50:51 AM 2025 AUC 0.927030664606182
#
# [mbo] 42: num_leaves=187; max_depth=14; learning_rate==0.00541; n_estimators=551; min_data_in_leaf=195; bagging_freq=7; bagging_fraction==0.833; feature_fraction==0.836; scale_pos_weight=143 : y = 0.927 : 364.2 secs : infill_ei
#
# Tue Nov 04 05:55:25 AM 2025 AUC 0.928066598005364
#
# [mbo] 43: num_leaves=30; max_depth=15; learning_rate==0.291; n_estimators=213; min_data_in_leaf=183; bagging_freq=2; bagging_fraction==0.815; feature_fraction==0.672; scale_pos_weight=103 : y = 0.928 : 272.6 secs : infill_ei
#
# Saved the current state after iteration 44 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:00:44 AM 2025 AUC 0.927309571510232
#
# [mbo] 44: num_leaves=240; max_depth=10; learning_rate==0.291; n_estimators=2561; min_data_in_leaf=193; bagging_freq=7; bagging_fraction==1; feature_fraction==0.642; scale_pos_weight=51 : y = 0.927 : 317.1 secs : infill_ei
#
# Tue Nov 04 06:06:57 AM 2025 AUC 0.927179777217144
#
# [mbo] 45: num_leaves=382; max_depth=14; learning_rate==0.0424; n_estimators=203; min_data_in_leaf=200; bagging_freq=8; bagging_fraction==0.845; feature_fraction==0.576; scale_pos_weight=114 : y = 0.927 : 370.8 secs : infill_ei
#
# Saved the current state after iteration 46 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:11:21 AM 2025 AUC 0.927875092386594
#
# [mbo] 46: num_leaves=24; max_depth=15; learning_rate==0.253; n_estimators=1307; min_data_in_leaf=157; bagging_freq=6; bagging_fraction==0.702; feature_fraction==0.794; scale_pos_weight=50 : y = 0.928 : 261.9 secs : infill_ei
#
# Tue Nov 04 06:15:32 AM 2025 AUC 0.928178833255848
#
# [mbo] 47: num_leaves=16; max_depth=14; learning_rate==0.0838; n_estimators=1202; min_data_in_leaf=200; bagging_freq=10; bagging_fraction==0.998; feature_fraction==0.96; scale_pos_weight=50 : y = 0.928 : 249.9 secs : infill_ei
#
# Tue Nov 04 06:20:20 AM 2025 AUC 0.926704682193512
#
# [mbo] 48: num_leaves=45; max_depth=15; learning_rate==0.0655; n_estimators=2996; min_data_in_leaf=189; bagging_freq=2; bagging_fraction==0.717; feature_fraction==0.869; scale_pos_weight=150 : y = 0.927 : 287.1 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:24:38 AM 2025 AUC 0.928199763792718
#
# [mbo] 49: num_leaves=20; max_depth=15; learning_rate==0.268; n_estimators=700; min_data_in_leaf=171; bagging_freq=1; bagging_fraction==0.726; feature_fraction==0.564; scale_pos_weight=50 : y = 0.928 : 256.8 secs : infill_ei
#
# Tue Nov 04 06:30:12 AM 2025 AUC 0.926474790189008
#
# [mbo] 50: num_leaves=327; max_depth=11; learning_rate==0.0925; n_estimators=1010; min_data_in_leaf=200; bagging_freq=5; bagging_fraction==0.995; feature_fraction==0.929; scale_pos_weight=50 : y = 0.926 : 332.3 secs : infill_ei
#
# Tue Nov 04 06:34:38 AM 2025 AUC 0.926407429812903
#
# [mbo] 51: num_leaves=25; max_depth=14; learning_rate==0.278; n_estimators=1158; min_data_in_leaf=179; bagging_freq=2; bagging_fraction==0.723; feature_fraction==0.981; scale_pos_weight=50 : y = 0.926 : 264.6 secs : infill_ei
#
# Saved the current state after iteration 52 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:38:59 AM 2025 AUC 0.92849302253559
#
# [mbo] 52: num_leaves=21; max_depth=15; learning_rate==0.174; n_estimators=540; min_data_in_leaf=196; bagging_freq=9; bagging_fraction==0.938; feature_fraction==0.779; scale_pos_weight=50 : y = 0.928 : 259.2 secs : infill_ei
#
# Tue Nov 04 06:45:15 AM 2025 AUC 0.92723080722239
#
# [mbo] 53: num_leaves=460; max_depth=14; learning_rate==0.298; n_estimators=454; min_data_in_leaf=200; bagging_freq=10; bagging_fraction==1; feature_fraction==0.753; scale_pos_weight=97 : y = 0.927 : 375.1 secs : infill_ei
#
# Saved the current state after iteration 54 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:50:54 AM 2025 AUC 0.929034915028062
#
# [mbo] 54: num_leaves=107; max_depth=15; learning_rate==0.0339; n_estimators=275; min_data_in_leaf=194; bagging_freq=10; bagging_fraction==0.999; feature_fraction==0.633; scale_pos_weight=52 : y = 0.929 : 337.0 secs : infill_ei
#
# Tue Nov 04 06:56:00 AM 2025 AUC 0.929117035409811
#
# [mbo] 55: num_leaves=64; max_depth=15; learning_rate==0.25; n_estimators=1104; min_data_in_leaf=198; bagging_freq=6; bagging_fraction==0.722; feature_fraction==0.617; scale_pos_weight=50 : y = 0.929 : 304.7 secs : infill_ei
#
# Saved the current state after iteration 56 in the file bayesiana.RDATA.
#
# Tue Nov 04 06:59:50 AM 2025 AUC 0.927289759309894
#
# [mbo] 56: num_leaves=18; max_depth=3; learning_rate==0.269; n_estimators=2811; min_data_in_leaf=189; bagging_freq=4; bagging_fraction==0.611; feature_fraction==0.578; scale_pos_weight=50 : y = 0.927 : 227.5 secs : infill_ei
#
# Tue Nov 04 07:04:43 AM 2025 AUC 0.927355056097157
#
# [mbo] 57: num_leaves=49; max_depth=15; learning_rate==0.0553; n_estimators=1053; min_data_in_leaf=199; bagging_freq=10; bagging_fraction==0.952; feature_fraction==0.657; scale_pos_weight=50 : y = 0.927 : 291.8 secs : infill_ei
#
# Tue Nov 04 07:09:58 AM 2025 AUC 0.928355869132437
#
# [mbo] 58: num_leaves=75; max_depth=15; learning_rate==0.279; n_estimators=238; min_data_in_leaf=179; bagging_freq=6; bagging_fraction==0.73; feature_fraction==0.744; scale_pos_weight=52 : y = 0.928 : 313.5 secs : infill_ei
#
# Saved the current state after iteration 59 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:15:43 AM 2025 AUC 0.929420876319687
#
# [mbo] 59: num_leaves=118; max_depth=15; learning_rate==0.197; n_estimators=515; min_data_in_leaf=199; bagging_freq=4; bagging_fraction==0.983; feature_fraction==0.788; scale_pos_weight=50 : y = 0.929 : 343.3 secs : infill_ei
#
# Tue Nov 04 07:21:23 AM 2025 AUC 0.928340474364652
#
# [mbo] 60: num_leaves=104; max_depth=15; learning_rate==0.177; n_estimators=560; min_data_in_leaf=198; bagging_freq=5; bagging_fraction==0.988; feature_fraction==0.781; scale_pos_weight=57 : y = 0.928 : 337.7 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:26:58 AM 2025 AUC 0.927822932356255
#
# [mbo] 61: num_leaves=101; max_depth=15; learning_rate==0.246; n_estimators=232; min_data_in_leaf=200; bagging_freq=6; bagging_fraction==0.935; feature_fraction==0.675; scale_pos_weight=50 : y = 0.928 : 333.1 secs : infill_ei
#
# Tue Nov 04 07:32:46 AM 2025 AUC 0.92735745794332
#
# [mbo] 62: num_leaves=137; max_depth=14; learning_rate==0.0977; n_estimators=2560; min_data_in_leaf=200; bagging_freq=7; bagging_fraction==0.687; feature_fraction==0.536; scale_pos_weight=50 : y = 0.927 : 346.6 secs : infill_ei
#
# Saved the current state after iteration 63 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:37:13 AM 2025 AUC 0.926608215631723
#
# [mbo] 63: num_leaves=25; max_depth=15; learning_rate==0.11; n_estimators=207; min_data_in_leaf=200; bagging_freq=2; bagging_fraction==0.759; feature_fraction==0.623; scale_pos_weight=131 : y = 0.927 : 265.2 secs : infill_ei
#
# Tue Nov 04 07:42:58 AM 2025 AUC 0.927166787284678
#
# [mbo] 64: num_leaves=118; max_depth=15; learning_rate==0.282; n_estimators=397; min_data_in_leaf=200; bagging_freq=1; bagging_fraction==0.83; feature_fraction==0.84; scale_pos_weight=116 : y = 0.927 : 343.2 secs : infill_ei
#
# Saved the current state after iteration 65 in the file bayesiana.RDATA.
#
# Tue Nov 04 07:47:08 AM 2025 AUC 0.926780379567339
#
# [mbo] 65: num_leaves=144; max_depth=5; learning_rate==0.0597; n_estimators=2330; min_data_in_leaf=200; bagging_freq=4; bagging_fraction==0.708; feature_fraction==0.68; scale_pos_weight=50 : y = 0.927 : 247.6 secs : infill_ei
#
# Tue Nov 04 07:51:57 AM 2025 AUC 0.927818274389869
#
# [mbo] 66: num_leaves=45; max_depth=15; learning_rate==0.295; n_estimators=320; min_data_in_leaf=200; bagging_freq=7; bagging_fraction==0.77; feature_fraction==0.571; scale_pos_weight=86 : y = 0.928 : 287.5 secs : infill_ei
#
# Tue Nov 04 07:55:56 AM 2025 AUC 0.92535767864833
#
# [mbo] 67: num_leaves=203; max_depth=4; learning_rate==0.254; n_estimators=2961; min_data_in_leaf=164; bagging_freq=8; bagging_fraction==0.697; feature_fraction==0.662; scale_pos_weight=50 : y = 0.925 : 237.7 secs : infill_ei
#
# Saved the current state after iteration 68 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:00:18 AM 2025 AUC 0.927791946988035
#
# [mbo] 68: num_leaves=23; max_depth=15; learning_rate==0.261; n_estimators=315; min_data_in_leaf=170; bagging_freq=1; bagging_fraction==0.961; feature_fraction==0.679; scale_pos_weight=51 : y = 0.928 : 260.7 secs : infill_ei
#
# Tue Nov 04 08:04:46 AM 2025 AUC 0.92768206837231
#
# [mbo] 69: num_leaves=24; max_depth=15; learning_rate==0.269; n_estimators=534; min_data_in_leaf=200; bagging_freq=4; bagging_fraction==0.771; feature_fraction==0.819; scale_pos_weight=52 : y = 0.928 : 265.5 secs : infill_ei
#
# Tue Nov 04 08:10:22 AM 2025 AUC 0.927032523366221
#
# [mbo] 70: num_leaves=107; max_depth=15; learning_rate==0.0285; n_estimators=303; min_data_in_leaf=179; bagging_freq=8; bagging_fraction==0.999; feature_fraction==0.872; scale_pos_weight=50 : y = 0.927 : 335.2 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:16:51 AM 2025 AUC 0.926158515940589
#
# [mbo] 71: num_leaves=507; max_depth=15; learning_rate==0.211; n_estimators=1682; min_data_in_leaf=200; bagging_freq=4; bagging_fraction==0.818; feature_fraction==0.783; scale_pos_weight=139 : y = 0.926 : 387.1 secs : infill_ei
#
# Tue Nov 04 08:21:34 AM 2025 AUC 0.927999896589085
#
# [mbo] 72: num_leaves=38; max_depth=11; learning_rate==0.287; n_estimators=819; min_data_in_leaf=195; bagging_freq=3; bagging_fraction==0.707; feature_fraction==0.644; scale_pos_weight=50 : y = 0.928 : 280.8 secs : infill_ei
#
# Saved the current state after iteration 73 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:27:46 AM 2025 AUC 0.928175889894369
#
# [mbo] 73: num_leaves=200; max_depth=15; learning_rate==0.114; n_estimators=2205; min_data_in_leaf=200; bagging_freq=7; bagging_fraction==1; feature_fraction==0.722; scale_pos_weight=50 : y = 0.928 : 370.7 secs : infill_ei
#
# Tue Nov 04 08:32:14 AM 2025 AUC 0.928563536962781
#
# [mbo] 74: num_leaves=26; max_depth=13; learning_rate==0.152; n_estimators=2728; min_data_in_leaf=200; bagging_freq=2; bagging_fraction==0.945; feature_fraction==0.846; scale_pos_weight=50 : y = 0.929 : 266.9 secs : infill_ei
#
# Saved the current state after iteration 75 in the file bayesiana.RDATA.
#
# Tue Nov 04 08:36:32 AM 2025 AUC 0.927765695760498
#
# [mbo] 75: num_leaves=20; max_depth=14; learning_rate==0.252; n_estimators=1012; min_data_in_leaf=200; bagging_freq=1; bagging_fraction==0.841; feature_fraction==0.542; scale_pos_weight=94 : y = 0.928 : 256.3 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_leaves"        "max_depth"         "learning_rate."
#  [4] "n_estimators"      "min_data_in_leaf"  "bagging_freq"
#  [7] "bagging_fraction." "feature_fraction." "scale_pos_weight"
# [10] "y"                 "dob"               "eol"
# [13] "error.message"     "exec.time"         "ei"
# [16] "error.model"       "train.time"        "prop.type"
# [19] "propose.time"      "se"                "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_leaves max_depth learning_rate. n_estimators min_data_in_leaf
#         <int>     <int>          <num>        <int>            <int>
# 1:        118        15       0.197076          515              199
#    bagging_freq bagging_fraction. feature_fraction. scale_pos_weight
#           <int>             <num>             <num>            <int>
# 1:            4         0.9826396         0.7879227               50
# [1] 0.9294209

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 557057
#
# $max_depth
# [1] 15
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.02
#
# $feature_fraction
# [1] 0.5
#
# $num_leaves
# [1] 118
#
# $min_data_in_leaf
# [1] 199
#
# $learning_rate.
# [1] 0.197076
#
# $n_estimators
# [1] 515
#
# $bagging_freq
# [1] 4
#
# $bagging_fraction.
# [1] 0.9826396
#
# $feature_fraction.
# [1] 0.7879227
#
# $scale_pos_weight
# [1] 50

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 09:43:47 AM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
